# %% [markdown]
# ### PROJETO DE CONSULTA POR SIMILARIDADE  - SPDO ###

# %% [markdown]
# ### Criando os embeddings ###

# %% [markdown]
# ### Requerimentos ###

# %%
import os, sys
# Garante que o cwd seja a raiz do projeto, independente de onde o notebook foi aberto
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

# !pip install -q -r requirements.txt
# %load_ext watermark

# %%
import pandas as pd
import numpy as np
import warnings
from src.similarity import gerar_embeddings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Criar embeddings dos dados padronizados ###

# %%
print('Carregando dados...')
df_embeddings = pd.read_csv('data/staging/df_embeddings.csv', engine='python')
df_embeddings.sample(10)

# %%
# Gerando os embeddings com SBERT e salvando em um arquivo parquet para ser usado posteriormente pelo modelo
print("Gerando embeddings...")
df_embeddings = gerar_embeddings(df_embeddings, ['INSUMO_DESCRICAO', 'MARCA', 'MEDIDA'])
df_embeddings.to_parquet('data/staging/embeddings_bp.parquet')

# %%
# %watermark --iversions
